# %% [markdown]
# <img src="./assets/ga-logo.png" style="float: left; margin: 20px; height: 55px">
#
#
# # Simple Linear Regression Using `scikit-learn`
#
#
# ---
#
# <img src="https://avatars2.githubusercontent.com/u/365630?v=3&s=400" style="width: 300px; float: left; margin: 20px; margin-top: -20px; break: right;">
#
# <br clear="all">
#
#
# ### Learning Objectives
# - Overview what the **scikit-learn modules** are used for
# - Learn how to build a **linear regression model with scikit-learn**
# - Practice building models using **scikit-learn**

# %% [markdown]
# <a id='intro'></a>
#
# ##  `sklearn`
#
# ---
#
# This lesson intends to introduce the modeling packages `sklearn` (also called scikit-learn) in the context of regression modeling.
#
# In general:
# - **`sklearn`** is the *machine learning* package
#
# **Remember: even with all the power provided by this modeling tools, it's never a replacement for good EDA!**

# %% [markdown]
# ---
#
# ### A preface on modeling
#
# As we venture down the path of modeling, it can be difficult to determine which choices are "correct" or "incorrect".  A primary challenge is to understand **how different models will perform** in different circumstances and different types of data. It's essential to **practice modeling on a variety of data**.
#
# As a beginner it is essential to learn **which metrics are important for evaluating your models and what they mean**. The metrics we evaluate our models with inform our actions.
#
# *Exploring datasets on your own with the skills and tools you learn in class is highly recommended!*

# %% [markdown]
# ### Note on `sciKit-learn` (called `sklearn` within the community):

# %% [markdown]
# `sklearn` is a part of the `sciKit-learn` project.
#
# `SciKits` is short for **SciPy Toolkits**.
#
# `SciPy` is a Python library used for **scientific computing and technical computing**.
#
# There is a huge community behind the Python/SciPy ecosystem.

# %% [markdown]
# <a id='documentation'></a>
#
# ## `sklearn` documentation
#
# ---
#
# Get familiar with looking up things in the `sklearn` documentation.
#
# [The sklearn documentation can be found here.](http://scikit-learn.org/stable/documentation.html)
#
# [Linear regression in scikit-learn](http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LinearRegression.html)
#
# If you haven't yet, familliarize yourself with the format of the documentation.

# %% [markdown]
# <a id='sklearn-background'></a>
#
# ## Background: Scikit-learn / sklearn
#
# ---
#
# <img src="https://avatars1.githubusercontent.com/u/25111?v=3&s=200" style="float: left; margin: 0 25px;"> Scikit-learn was founded in 2007 as a Google summer of code project by [David Cournapeau](https://github.com/cournape).  Later in 2007, Matthieu Brucher published his thesis on Scikit-learn.  Since then, the Scikit-learn project has taken on a worldwide team of owners. A great high level overview of the project can be found in a 2011 publication in [Journal of Machine Learning Research 12 (2011) 2825-2830](http://www.jmlr.org/papers/volume12/pedregosa11a/pedregosa11a.pdf).
#
# Skikit-learn is part of the Scipy (pronounced “Sigh Pie”) family of "kits".
# <br clear="all"><br>
#
#
# **Scikit-learn provides a wide variety of machine learning models, including:**
#
# - Linear regression
# - Logistic regression
# - Support Vector Machines
# - Classification And Regression Tree Models
# - Naive Bayes
# - Clustering Models (K-Means, Hierarchical, DBScan)
#
# **It also handles the construction of typical machine learning pipeline utilities for:**
# - Model evaluation
# - Model selection
# - Preprocessing
# - Natural Language Processing
# - Dimensionality Reduction
#
# **Scikit-learn comes with a ton of datasets that are cleaned and formatted to work with the models provided by their library:**
# - Boston Housing
# - Iris Flowers
# - Diabetes Diagnostics
# - Various sample images (for classification)
#   - Faces
#   - MINIST (handwriting examples)
# - Random data generators
# - Spam examples
# - Newsgroup classfication
#
# [Read more about Scikit-learn datasets](https://scikit-learn.org/stable/api/sklearn.datasets.html#module-sklearn.datasets)
#
# ---

# %% [markdown]
# ### `sklearn` under the hood
#
# - **Numpy**:  is a library for the Python programming language, adding support for large, multi-dimensional arrays and matrices, along with a large collection of high-level mathematical functions to operate on these arrays.The base for data structures and transformations. Input data is represented as numpy arrays, integrating seamlessly with other scientific Python libraries. It also provides basic arithmetic and linear algebra operations.<br><br>
#
# ![NumPy.PNG](attachment:NumPy.PNG)

# %% [markdown]
# - **SciPy **:  Efficient algorithms for **linear algebra, sparse matrix representation, special functions and basic statistical functions.**<br><br>
#
# ![SciPy.PNG](attachment:SciPy.PNG)
#
# - **Cython**:  A language for combining C with Python. Cython makes it easy to reach the performance of compiled languages with Python-like syntax and high-level operations.

# %% [markdown]
# ## Baseline Prediction (The Null model)

# %% [markdown]
# <details><summary>I have my data in hand. If I want to generate the same predicted $y$ value for all of my observations, what is the best $y$ value for me to predict?</summary>
#
# - I will probably use the mean of my $y$ values, $\bar{y}$ (called y bar).
# </details>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![residuals_mean.png](attachment:residuals_mean.png)

# %% [markdown]
# The blue lines in `Image1` plot are the differences between the real $y$ values and the average $\bar{y}$ value

# %% [markdown]
# ## Finding the "best" slope and intercept

# %% [markdown]
# ![residuals_line.png](attachment:residuals_line.png)

# %% [markdown]
# <details><summary>Which model is better: the one in image 1 or the one in image 2? Why?</summary>
#
# - The model in image 2 is probably better.
# - Our gaps between the model and the data look smaller in image 2. (There's less blue in image 2 than in image 1!)
# </details>

# %% [markdown]
# ## Lines
#
# This was the equation I learned for a line. Look familiar?
# $$ \huge y = mx + b$$
# In data science it gets changed to
#
# $$ \huge  y = \beta_0 + \beta_1 x_1 $$
#
# ### Errors
#
# Our model isn't going to be perfect. The things our model doesn't capture are errors and denoted by $\epsilon$ (epsilon).
#
# $$ \huge y = \beta_0 + \beta_1 x_1 + \epsilon $$
#
# ### OLS (Ordinary Least Squares) Regression Modeling
#
# We have _x_ and we have _y_. That's our data.
#
# Our model is trying to figure out the best betas.
#
# $$ \huge \hat y =  \beta_0 +  \beta_1 x_1 $$
#
#
# $\hat \beta_0$ is the y-intercept that our model learns. The point where the line crosses the y-axis.
#
# $\hat \beta_1$ is the coefficient that we multiply by our $x_1$ variable. It's the slope. For every 1 unit it change in $x_1$, y increases by the value of $\beta1$.
#
# When we have a model that has been fit with the data the betas have been computed. We can plug in a new x value and solve for $\hat y$.
#
#
# #### $\hat y$ is a prediction! 🎉

# %% [markdown]
# ## Finding Best `Slope` and `Intercept`

# %% [markdown]
# If we want to find the "best" slope and intercept, we need to:
# 1. **have some criteria defining what it means to be the "best,"** and
# 2. **be able to optimize this criteria.**
#
#
# ### Residuals/Errors
#
# The difference between the true value of $y$ and the predicted value of $y$ (denoted $\hat{y}$, "y-hat") is known as a "residual" or an "error." We use these terms interchangeably!
#
# For every value of $i$ from 1 to $n$, we:
# - have an observed $x_i$.
# - have an observed $y_i$.
# - can calculate a predicted value $\hat{y}_i$ (predicted from our model).
# - can calculate a residual $\varepsilon_i = y_i - \hat{y}_i$.
#
# ##### Made up example of $x_i$, $y_i$, $\hat{y}_i$, and $\varepsilon_i$:
#
#
# |  $x_i$| $y_i$   | $\hat{y}_i$ | $\varepsilon_i$ |
# |-----  |---------|-------      |----------       |
# | 1     | 49      | 50          | -1              |
# | 2     | 102     | 100         | +2              |
# | 3     | 151     | 150         | +1              |
# | 4     | 198     | 200         | -2              |

# %% [markdown]
# <a id='common-metrics'></a>
#
# ## Common metrics for evaluating regression models
#
# ---
#
#
# ### Root Mean Squared Error (RMSE)
#
# **The [root mean squared error (RMSE)](https://en.wikipedia.org/wiki/Root-mean-square_deviation) is a standard measure of model performance.**
# - It is the square root of the mean of the sum of squared `residuals`.
# - RMSE is expressed in the exact same units as the target variable (e.g., if predicting house prices in dollars, RMSE is directly interpreted in dollars):
#
# ### $$ \operatorname{RMSE}= \sqrt{\frac{1}{n}\sum_{i=1}^n(y_i - \hat{y_i})^2} $$
#
# The smaller the root mean squared error, the better your model fits the data.
#
# **Calculate the RMSE of your model by leveraging `sklearn.metrics.mean_squared_error`.**
#
#
#
# ### The Coefficient of Determination ($R^2$)
# (https://en.wikipedia.org/wiki/Coefficient_of_determination):
#
# **$R^2$ is the most common metric to evaluate a regression and is the default scoring measure in sklearn.** When we cover classification models, the `.score` function instead defaults to accuracy.
#
# ### $$ R^2 = 1 - \frac{SS_{res}}{SS_{tot}} $$
#
# Where the regression sum of squares is the sum of squared residuals for our model:
#
# $SS_{res}=\sum_i (y_i - \hat{y})^2$
#
# And the total sum of squares is the sum of squared residuals for the *baseline* model. This is essentially the variance of our target.
#
# $SS_{tot} = \sum_i (y_i-\bar{y})^2$

# %% [markdown]
# <a id='sklearn-first-steps'></a>
#
# ## First steps with `sklearn`: loading the data
#
# ---
#
# We will load the boston housing dataset  then construct and fit a linear regression model on the data.

# %%
# You have to install the below two libraries before you are ablt to use them
# %pip install seaborn
# %pip install sciKit-learn

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt     # or  from matplotlib import pyplot as plt
import seaborn as sns
from math import sqrt

#from sklearn.datasets import load_boston

from sklearn import datasets
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn import metrics

import warnings
warnings.filterwarnings("ignore")

# Don't forget to turn on plotting display in the notebook
# %matplotlib inline

# %autosave 0

# %% [markdown]
# ## Loading Boston Housing Dataset

# %%
df = pd.read_csv("./data/BostonHousing2.csv")
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         B  LSTAT  PRICE
# 0  396.90   4.98   24.0
# 1  396.90   9.14   21.6
# 2  392.83   4.03   34.7
# 3  394.63   2.94   33.4
# 4  396.90   5.33   36.2

# %% [markdown]
# #### Boston Housing Data Dictionary
#
#     The Boston Housing Dataset
#
#     The Boston Housing Dataset is a derived from information collected by the U.S. Census Service concerning housing in the area of Boston MA. The following describes the dataset columns:
#
#     CRIM - per capita crime rate by town
#     ZN - proportion of residential land zoned for lots over 25,000 sq.ft.
#     INDUS - proportion of non-retail business acres per town.
#     CHAS - Charles River dummy variable (1 if tract bounds river; 0 otherwise)
#     NOX - nitric oxides concentration (parts per 10 million)
#     RM - average number of rooms per dwelling
#     AGE - proportion of owner-occupied units built prior to 1940
#     DIS - weighted distances to five Boston employment centres
#     RAD - index of accessibility to radial highways
#     TAX - full-value property-tax rate per $10,000
#
#     PTRATIO - pupil-teacher ratio by town
#     B - 1000(Bk - 0.63)^2 where Bk is the proportion of blacks by town
#     LSTAT - % lower status of the population
#     PRICE - Median value of owner-occupied homes in $1000's

# %% [markdown]
# ### Putting the data in pandas for convenience
#
# Our **target is what we are predicting**.  Sometimes this is called the **dependent variable**.
#
# The target and the data are what we use to train, or **fit** the model with.
#
# In Boston housing dataset, our target is `PRICE` and our predictors are some of the other features/columns in the dataset

# %% [markdown]
# ### Index correspondence between target and predictors
#
# Row 0 of **`df`**, our training data, is:
#
# ```
# [0.00632	18.0	2.31	0.0	0.538	6.575	65.2	4.0900	1.0	296.0	15.3	396.90	4.98]
# ```
#
# This corresponds to the 0 index obersvation in our target vector:
# ```
# 24.0
# ```
#
# These two seperate datasets (a matrix/dataframe, and a vector), are what we will use in the `.fit(predictors, target)` function in sklearn's models.
#
# - The training data is 2D with dimensions: `n_samples x n_features`
# - The response is 1D with dimensions: `n_samples`, matching the `n_samples` of the training data.

# %% [markdown]
# <a id='first-model-sklearn'></a>
#
# ## Fitting our 1st model with `sklearn`
#
# ---
#
# Now let's fit a linear regression model with the housing data.
#
# First let's visually identify some predictors that seem to have a relationship with house value.
#
# **Plot RM and LSTAT against the target variable with seaborn.**
#
# > _Note: If for some reason scikit-learn crashes the jupyter notebook, have conda remove mkl (there's an issue with the newer build on some systems)._

# %%
#Draw a plot of two variables with bivariate and univariate graphs 
# target vs RM (average number of rooms)
# use seaborn plot library sns.scatterplot


# plt.show()

# %%
# from seaborn library, do jointplot
# target vs LSTAT


# plt.show()
# Right (target), Top (LSTAT)

# %% [markdown]
# ### Step 1: Assemble our predictor variables (X) and our target (y)
#
# **Below we fit a linear regression model predicting `PRICE` (the target vector) from `RM`.**
#
# > **Note:** sklearn models expect the predictor matrix to be 2D and the target to be 1D.

# %%
# Selecting Which features will be predictors. AKA "X" (Using capital X is very commonly used in ML for predictors)

# X=features, y=target

# set the variable "RM=X" and target=y





# X.head()

# %%
# display y

# %%
# check the type of y

# %% [markdown]
# ### Step 2: Instantiate the model

# %%
# initiate a model called model1 as "LinearRegression"

# %% [markdown]
# ### Step 3: Fit the model

# %%
# we fit a linear regression model predicting PRICE (the target vector) from RM
# perform fit function in model1 for X (RM) & y (PRICE)

# %% [markdown]
# ### Step 4: Evaluation

# %% [markdown]
# **Make predictions for the X matrix using `.predict(X)`, and score the model ($R^2$) using `model.score(X, y)`.**
#
# Plot the predicted values against the true values of the target, and print the model $R^2$.
#
# > **`.score(predictors, target)`**: a class method / function that returns the coefficient of determination $R^2$ of the prediction (for regression models).  Found in many models in scikit-learn (but not all).

# %%
# print R-squared (Coefficient of determination). By default, score returns the coefficient of 
# determination(R-squared, R2) score:
# X=RM, y=target

# %% [markdown]
# ### Step 5: Make predictions
#
# If we had new data points for RM, we could pass it to the predict method to generate price predictions.
#
# We don't have any new data, so let's just see what predictions our model would have made. This is the same as saying "Find the x value for a prediction on the plot and go up to our line. That value for y is our prediction."
#
# We do this for all the x values.

# %%
# Doing the prediction of X to get the y-hat
# save the result in variable called y_pred

# %%
# show 5 rows values of y_pred predictions

# %%
# show 5 rows of actual values of y

# %%
# show a table of predictions vs actual 
# Actual 5 rows y values vs. y_pred values

# %%
# Plot the model ... predicted_target vs actual_target ( or vice versa)
plt.figure(figsize=(16, 8))

# 1. original scatter plot
plt.scatter(y, y_pred, c='r', marker='+', label='Predictions') 

# 2. Add the regression reference line (Perfect Fit Line)
# This calculates the min and max limits based on data range
line_coords = np.linspace(min(y.min(), y_pred.min()), max(y.max(), y_pred.max()), 100)
plt.plot(line_coords, line_coords, c='blue', linestyle='--', linewidth=2, label='Perfect Fit')

# 3. Formatting
plt.xlabel("Actual Values PRICE - y")
plt.ylabel("Predicted Values of PRICE from RM - $\hat{y}$")
plt.legend() # Displays the labels for the dots and the line
plt.grid(True, alpha=0.3) # Optional: adds a subtle grid for better readability
plt.show()

# %% [markdown]
# ### What can be concluded?
# - if  R-squared value < 0.3 this value is generally considered a None or Very weak effect size,
# - if R-squared value 0.3 < r < 0.5 this value is generally considered a weak or low effect size,
# - if R-squared value 0.5 < r < 0.7 this value is generally considered a Moderate effect size,
# - if R-squared value r > 0.7 this value is generally considered strong effect size,
#
# Ref: Source: Moore, D. S., Notz, W. I, & Flinger, M. A. (2013). The basic practice of statistics (6th ed.). New York, NY: W. H. Freeman and Company. Page (138)

# %% [markdown]
# <a id='model-attributes'></a>
#
# ## sklearn model class attributes
#
# ---
#
# After you run `.fit()`, a sklearn model object often contains a variety of calculated metrics, coefficients, and other information. Which metrics and attributes are present will depend on the model – consult the documentation for specifics.
#
# Attributes in the `LinearRegression` object include:
# - **`.coef_`**: property containing the coefficients for the predictor variables
# - **`.intercept_`**: value of the intercept
#
# **Print out the beta coefficient and intercept for the model.**

# %%
# print model.coef_ and model1.intercept_

# %%
# Manual calculation of the prediction if x = 6.2
# y = c + mx

# %%
# doing single prediciton using the model prediction

# %% [markdown]
# #### **Calculate the RMSE of your model by leveraging 'sklearn.metrics.mean_squared_error'**

# %%
# Compute RMSE


# average value between actual target and predicted target, MSE

 
# RMSE by taking the square root of MSE

# %% [markdown]
# <a id='negative-r2'></a>
#
# ## A note on negative $R^2$ values
#
# ---
#
# Over the course of this class you will encounter negative $R^2$ values. This may seem impossible, and it is in the standard scenario where we are calculating the $R^2$ score on the data we fit the model with.
#
# However, if you fit your model on **one sample of data**, *then **score the model** on new data not used to fit the model*, it is possible to end up with negative $R^2$.
#
# **What does it mean to have a negative $R^2$?**
#
# Remember that $R^2$ is 1 minus the error of your regression model divided by the error of the baseline model. A negative $R^2$ means that **the regression model is performing *worse* than the baseline model**. In the context of fitting our data on one sample of data and scoring on another sample, this means that we would have been better off **making predictions** on the test sample just using **the mean of the target variable** in our training set.
#
# We will return to the topic of negative $R^2$ when we talk about training and testing sets and cross-validation.

# %% [markdown]
# <a id='assumptions'></a>
#
# ## Assumptions of Simple Linear Regression (SLR)
#
# ---
#
# There are some critical assumptions involved in SLR of which you **must** be aware:
#
# 1. **Linearity:** $Y$ must have an approximately linear relationship with each independent $X_i$.
# 2. **Independence:** Errors (residuals) $\varepsilon_i$ and $\varepsilon_j$ must be independent of one another for any $i \ne j$.
#     - A classic violation is time-series data (e.g., stock prices day-by-day), where today's price is highly dependent on yesterday's price
# 3. **Normality:** The errors (residuals) follow a Normal distribution with mean 0.
# 4. **Equality of Variances**: The errors (residuals) should have a roughly consistent pattern, regardless of the value of the $X_i$ predictors.
#
#
# The mnemonic `LINE` is a useful way to remember these four assumptions.

# %% [markdown]
# ### Let's check above assumptions with our model

# %% [markdown]
# 1. **Linearity:** $Y$ must have an approximately linear relationship with each independent $X_i$.

# %%
# 1. L - Linearity
# plt.scatter(X['RM'], y, s=1); #s is size

# %% [markdown]
# <details><summary>Does this pass our L assumption?</summary>
# It's definitely a little curved, but this looks okay.
# </details>

# %% [markdown]
# 2. **Independence:** Errors (residuals) $\varepsilon_i$ and $\varepsilon_j$ must be independent of one another for any $i \ne j$.

# %%
# 2. I - Independence

# %% [markdown]
# <details><summary>Does this pass our I assumption?</summary>
# Yes, by assumption.
# </details>

# %% [markdown]
# 3. **Normality:** The errors (residuals) follow a Normal distribution with mean 0.

# %%
# N - Normality of errors
# plt.hist(y-y_pred, bins=50);

# %% [markdown]
# <details><summary>Does this pass our N assumption?</summary>
# Just like with the Linearity assumption, this isn't great, but we might be able to get away with it.
# </details>

# %% [markdown]
# 4. **Equality of Variances**: The errors (residuals) should have a roughly consistent pattern, regardless of the value of the $X_i$ predictors.

# %%
# E - Equal variance of errors
# plt.scatter(y_pred, y-y_pred, s=1)
# plt.axhline(0, color="orange");

# %% [markdown]
# <details><summary>Does this pass our E assumption?</summary>
# I'm gonna go with no on this one...
# </details>

# %% [markdown]
# <a id='mlr-sklearn'></a>
#
# ## Fit a Multiple Linear Regression (MLR) using sklearn
#
# ---
#
# We have fit a simple linear regression predicting `PRICE ~ RM + intercept` . Use the same sklearn process and `LinearRegression` model to estimate the target with both `RM` and `LSTAT`.

# %% [markdown]
# **Print out the coefficients from this MLR model and interpret them.**

# %%
# initiate model2 as LinearRegression model



# set model features X as RM and LSTAT columns
# set the target y as price



# Do model2 fitting for X and y



# make predictions for X, save as y_pred2


# make a variabel score to save the R-squared score of model2



# print R-squared

# %%
# what is model2 intercept value?

# %%
# what is model2 coefficients?
# Notice we have two coefficients

# %%
# Plot the model
plt.figure(figsize=(16, 8))

# 1. original scatter plot
plt.scatter(y, y_pred2, c='r', marker='+', label='Predictions') 

# 2. Add the regression reference line (Perfect Fit Line)
# This calculates the min and max limits based on data range
line_coords = np.linspace(min(y.min(), y_pred2.min()), max(y.max(), y_pred2.max()), 100)
plt.plot(line_coords, line_coords, c='blue', linestyle='--', linewidth=2, label='Perfect Fit')

# 3. Formatting
plt.xlabel("Actual Values PRICE - y")
plt.ylabel("Predicted Values of PRICE from RM + LSTAT - $\hat{y}$")
plt.legend() # Displays the labels for the dots and the line
plt.grid(True, alpha=0.3) # Optional: adds a subtle grid for better readability
plt.show()

# %% [markdown]
# ## In-Class Exercise
#
# #### First model Simple Linear Regression (SLR)
#
# - Using the diamond dataset, predict the `price` based on `carat` feature

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# read diamonds.csv file
# diamond=

# %%
# show the first 5 rows of the diamond dataframe

# %%
# show how many colors and value counts for each color from color column
# hint: use value_counts

# %%
# show the details for the columns and their type using .info()

# %%
# show the coorelation between all the columns using .corr(numeric_only=True)

# %%
# use jointplot to plot 'carat' against the diamond 'price'


# plt.show()

# %%
# set X3 to be the 'carat' and y3 to be 'price' as the target 
# Note: X3 must be a dataframe type. remember how to do it 
# from python lectures, note also that y is a 1D series (not a dataframe)

# %%
# initiate model3 as the linear regression model

# %%
# Do the fitting (learning and getting the model coefficients)

# %%
# show what the intercept value is

# %%
# show what the coefficient value is

# %%
# what is R2 score value?

# %% [markdown]
# > Do a prediction when `carat` = 0.34

# %%
# using .predict to predict the price when carat=0.34
# note: write the value inside double square brackets or you will get error

# %% [markdown]
# #### Second model Multiple Linear Regression (MLR)
#
# - Using the diamond dataset, predict the `price` based on `carat`,`depth`, `table`,`x`,`y`,`z` feature

# %%
# use X4 for the features list and y4 for the target price
# Note: X4 must be a dataframe type. remember how to do it 
# from python lectures, note also that y is a 1D series (not a dataframe)

# %%
# initiate model4 as the linear regression model

# %%
# Do the fitting (learning and getting the model coefficients)

# %%
# show what the intercept value is

# %%
# show what the coefficient values are (many coefficient here)

# %%
# what is R2 score value?

# %% [markdown]
# Predict the price when the values as follows:
#    1. carat = 0.34
#    2. depth = 60.2
#    3. table = 64
#    4. x = 4.15
#    5. y = 3.94
#    6. z = 2.29

# %%
# using .predict to predict the price
# note: write the value inside double square brackets or you will get error

# %%
# Plot the model
plt.figure(figsize=(16,8))
plt.scatter(model4.predict(X4), y4, c='b', marker='+' , s=70)
plt.xlabel("Predicted Values y-hat")
plt.ylabel("Actual Values y")
plt.show()
